# %% [markdown]
# #Dictionary = Key value pair

# %%
MonthNames = {
    "Jan":"Januray",
    "Feb":"Feburary",
    "Mar":"March"
}

# %%
print(MonthNames)
# Out:
# {'Jan': 'Januray', 'Feb': 'Feburary', 'Mar': 'March'}

# %%
MonthNames["Jan"]
# Out:
# 'Januray'

# %%
MonthNames["May"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-78e36eeb007f> in <module>
# ----> 1 MonthNames["May"]
#
# KeyError: 'May'
