# %%
def sayHello():
    print("Hey there!")

# %%
sayHello()
# Out:
# Hey there!

# %%
def sayHello(name):
    print("Hey there!",name)

# %%
sayHello("Mohan")
# Out:
# Hey there! Mohan

# %%
def sayHello(name):
    print("Hey there! " + name)
    
sayHello("Mohan")
# Out:
# Hey there! Mohan

# %%
def GetResult(a,b):
    return a+b

# %%
print(GetResult(1,2))
# Out:
# 3

# %%
print(GetResult("hey"," there"))
# Out:
# hey there

# %%
def GetSumAndMultiple(a,b):
    return a+b,a*b

# %%
_sum,_multiple = GetSumAndMultiple(8,9)
print(_sum,_multiple)
# Out:
# 17 72
