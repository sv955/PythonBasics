# %%
friends = []

# %%
type(friends)
# Out:
# list

# %%
friends = ["Shyam","Mohan","Rohan"]

# %%
friends
# Out:
# ['Shyam', 'Mohan', 'Rohan']

# %%
friends = ["Shyam","Mohan","Rohan",0]

# %%
friends
# Out:
# ['Shyam', 'Mohan', 'Rohan', 0]

# %%
a = friends[0]
type(a)
# Out:
# str

# %%
b = friends[3]
type(b)
# Out:
# int

# %%
friends = ["Shyam","Mohan","Rohan","Amit","Shubham","Aman","Abhay"]

# %%
friends[1:]
# Out:
# ['Mohan', 'Rohan', 'Amit', 'Shubham', 'Aman', 'Abhay']

# %%
friends[1:5]
# Out:
# ['Mohan', 'Rohan', 'Amit', 'Shubham']

# %%
friends[:-1]
# Out:
# ['Shyam', 'Mohan', 'Rohan', 'Amit', 'Shubham', 'Aman']

# %%
lucky_numbers = [1,2,3,4,5,6,7]

# %% [markdown]
# #Append list

# %%
ExtendedList = friends.copy()
ExtendedList.extend(lucky_numbers)
print(ExtendedList)
# Out:
# ['Shyam', 'Mohan', 'Rohan', 'Amit', 'Shubham', 'Aman', 'Abhay', 1, 2, 3, 4, 5, 6, 7]

# %%
AppnededList = friends.copy()
AppnededList.append(lucky_numbers)
print(AppnededList)
# Out:
# ['Shyam', 'Mohan', 'Rohan', 'Amit', 'Shubham', 'Aman', 'Abhay', [1, 2, 3, 4, 5, 6, 7]]

# %%
AppnededList = friends.copy()
AppnededList.insert(7,"Ramesh")
print(AppnededList)
# Out:
# ['Shyam', 'Mohan', 'Rohan', 'Amit', 'Shubham', 'Aman', 'Abhay', 'Ramesh']
