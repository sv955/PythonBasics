# %%
number = int(input("Enter a number "))
print("Your input is "+ str(number))
# Out:
# Enter a number 100
# Your input is 100

# %%
number = int(input("Enter a number "))
print("Your input is "+ str(number))
# Out:
# Enter a number abcd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1905fad61de8> in <module>
# ----> 1 number = int(input("Enter a number "))
#       2 print("Your input is "+ str(number))
#
# ValueError: invalid literal for int() with base 10: 'abcd'

# %%
try:
    number = int(input("Enter a number "))
    print("Your input is "+ str(number))
except:
    print("Invalid input")
# Out:
# Enter a number k
# Invalid input

# %%
try:
    print(100/0)
    number = int(input("Enter a number "))
    print("Your input is "+ str(number))
except ValueError as err:
    print("Value input error. ",err)
except ZeroDivisionError as err2:
    print("Divison by zero. ",err2)
# Out:
# Divison by zero.  division by zero

# %%
try:
    number = int(input("Enter a number "))
    print("Your input is "+ str(number))
except ValueError as err:
    print("Value input error.", err)
except ZeroDivisionError as err2:
    print("Divison by zero.",  err2)
# Out:
# Enter a number sld
# Value input error. invalid literal for int() with base 10: 'sld'
