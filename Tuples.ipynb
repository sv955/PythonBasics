# %% [markdown]
# #Tuples are immutable

# %%
coordinates = (4,5)

# %%
type(coordinates)
# Out:
# tuple

# %%
print(coordinates)
# Out:
# (4, 5)

# %%
new_coordinates = [(4,5),(10,1),(9,9)]

# %%
print(new_coordinates)
# Out:
# [(4, 5), (10, 1), (9, 9)]
